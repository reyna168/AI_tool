# %%
# 拉取项目
# !git clone https://github.com/Qiyue0726/AiSub.git
# Out:
# Cloning into 'AiSub'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 37 (delta 0), reused 37 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (37/37), 145.80 KiB | 20.83 MiB/s, done.

# %%
# 配置环境
# %cd /content/AiSub/

# !apt install ffmpeg

# !pip install -r requirements.txt
# Out:
# /content/AiSub
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 39.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 53.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 10.0 MB/s eta 0:00:00
# ...

# %%
# 检查设备信息
import torch

print("PyTorch版本:", torch.__version__)
print("CUDA是否可用:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("CUDA版本:", torch.version.cuda)
    print("GPU数量:", torch.cuda.device_count())
    print("当前GPU:", torch.cuda.get_device_name(0))
    print("GPU显存:", torch.cuda.get_device_properties(0).total_memory / 1024**3, "GB")
else:
    print("CUDA不可用，将使用CPU处理")
# Out:
# PyTorch版本: 2.8.0+cu126
# CUDA是否可用: True
# CUDA版本: 12.6
# GPU数量: 1
# 当前GPU: Tesla T4
# GPU显存: 14.74127197265625 GB

# %%
# !python main.py info
# Out:
# 🔍 AiSub 系统信息
# ...
# 2025-08-25 14:21:20,169 - src.utils.external_transcriber - INFO - Gemini 转录器初始化成功
# 2025-08-25 14:21:20,169 - src.utils.external_transcriber - WARNING - OpenAI 转录器初始化失败: OpenAI API key is required. Set OPENAI_API_KEY environment variable or config.
# 2025-08-25 14:21:20,170 - src.aisub_app - INFO - 可用的转录引擎: whisper, gemini
# 2025-08-25 14:21:20,170 - src.aisub_app - INFO - AiSub 应用程序初始化完成
# 📁 配置文件: config.yaml
# 🎬 支持的视频格式: .mp4, .avi, .mov, .mkv, .wmv, .flv, .webm, .m4v, .3gp, .ts, .mts, .m2ts
#
# 🤖 可用的 Whisper 模型:
#    tiny         - 参数:      39M, 显存:   ~1GB, 速度: ~32x
#    base         - 参数:      74M, 显存:   ~1GB, 速度: ~16x
#    small        - 参数:     244M, 显存:   ~2GB, 速度: ~6x
#    medium       - 参数:     769M, 显存:   ~5GB, 速度: ~2x
#    large        - 参数:    1550M, 显存:  ~10GB, 速度: ~1x
#    large-v2     - 参数:    1550M, 显存:  ~10GB, 速度: ~1x
#    large-v3     - 参数:    1550M, 显存:  ~10GB, 速度: ~1x
#
# 🖥️  设备信息:
#    CUDA 可用: 是
#    GPU 数量: 1
#    GPU 0: Tesla T4 (14.7 GB)
# ...

# %%
# 生成字幕
# !python main.py transcribe /content/test.flv -m large
# Out:
# 🎬 AiSub - 开始处理视频: /content/test.flv
# 2025-08-25 14:22:52,909 - src.utils.external_transcriber - INFO - Gemini 转录器初始化成功
# 2025-08-25 14:22:52,910 - src.utils.external_transcriber - WARNING - OpenAI 转录器初始化失败: OpenAI API key is required. Set OPENAI_API_KEY environment variable or config.
# 2025-08-25 14:22:52,910 - src.aisub_app - INFO - 可用的转录引擎: whisper, gemini
# 2025-08-25 14:22:52,910 - src.aisub_app - INFO - AiSub 应用程序初始化完成
# 处理进度  [------------------------------------]    0%2025-08-25 14:22:52,912 - src.aisub_app - INFO - 开始处理视频: /content/test.flv
# 2025-08-25 14:22:53,050 - src.utils.ffmpeg_wrapper - INFO - FFmpeg 找到: ffmpeg
# 2025-08-25 14:22:53,056 - src.utils.whisper_transcriber - INFO - 检测到 NVIDIA CUDA 支持
# 2025-08-25 14:22:53,056 - src.utils.whisper_transcriber - INFO - 使用设备: cuda
# 2025-08-25 14:22:53,056 - src.utils.whisper_transcriber - INFO - 正在加载 Whisper large 模型...
# 2025-08-25 14:22:53,057 - src.utils.whisper_transcriber - INFO - 模型参数: 1550M, 预计显存: ~10GB, 相对速度: ~1x
# ...
